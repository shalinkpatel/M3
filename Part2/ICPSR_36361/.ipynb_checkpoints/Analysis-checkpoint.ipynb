# %%
library(ggplot2)
setwd("/Users/shalinpatel/Documents/Drive\ Sync/BCA/12th\ Grade/M3/Part2/ICPSR_36361/")
load("DS0001/36361-0001-Data.rda")

# %%
ggplot(data = da36361.0001, mapping = aes(x = RKFQDBLT, y = ALCTRY)) + geom_violin(fill = "violet", alpha = 0.5) + geom_boxplot(fill = "green", alpha = 0.7, width = 0.1)
# Out:
# Warning message:
# “Removed 15120 rows containing non-finite values (stat_ydensity).”Warning message:
# “Removed 15120 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
head(da36361.0001)
# Out:
#   CASEID QUESTID2 CIGEVER CIGOFRSM           CIGWILYR           CIGTRY CIGYFU
# 1 1      85314767 (1) Yes NA                 NA                 16     NA
# 2 2      16240983 (1) Yes NA                 NA                 16     NA
# 3 3      95206287 (2) No  NA                 NA                 NA     NA
# 4 4      91546127 (2) No  NA                 NA                 NA     NA
# 5 5      43902390 (2) No  NA                 NA                 NA     NA
# 6 6      16475425 (2) No  (4) Definitely Not (4) Definitely Not NA     NA
#   CIGMFU CIGREC                       CIG30USE ⋯
# 1 NA     (04) More than 3 years ago   NA       ⋯
# 2 NA     (01) Within the past 30 days  1       ⋯
# 3 NA     NA                           NA       ⋯
# 4 NA     NA                           NA       ⋯
# 5 NA     NA                           NA       ⋯
# 6 NA     NA                           NA       ⋯
#   II2EMST4                                 PRXRETRY
# 1 (1) Employment status from questionnaire NA
# 2 (1) Employment status from questionnaire NA
# 3 (1) Employment status from questionnaire NA
# 4 (1) Employment status from questionnaire NA
# 5 (1) Employment status from questionnaire NA
# 6 (9) 12-17 years old                      NA
#   PDEN10                                                COUTYP2
# 1 (2) Segm. in a CBSA with fewer than 1 million persons (2) Small Metro
# 2 (1) Segment in a CBSA with 1 million or more persons  (1) Large Metro
# 3 (2) Segm. in a CBSA with fewer than 1 million persons (2) Small Metro
# 4 (1) Segment in a CBSA with 1 million or more persons  (1) Large Metro
# 5 (1) Segment in a CBSA with 1 million or more persons  (1) Large Metro
# 6 (1) Segment in a CBSA with 1 million or more persons  (1) Large Metro
#   MAIIN102
# 1 (2) Segment not in an American Indian area
# 2 (2) Segment not in an American Indian area
# 3 (2) Segment not in an American Indian area
# 4 (2) Segment not in an American Indian area
# 5 (2) Segment not in an American Indian area
# 6 (2) Segment not in an American Indian area
#   AIIND102                                        ANALWT_C   VESTR VEREP
# 1 (2) Census block not in an American Indian area  8587.8286 40025 2
# 2 (2) Census block not in an American Indian area  4260.6866 40041 1
# 3 (2) Census block not in an American Indian area   874.4788 40010 1
# 4 (2) Census block not in an American Indian area  4816.3811 40019 2
# 5 (2) Census block not in an American Indian area 18967.3918 40016 2
# 6 (2) Census block not in an American Indian area  2255.1806 40034 2
#   GQTYPE2
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA
